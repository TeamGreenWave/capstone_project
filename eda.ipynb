# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
gdp = pd.read_csv("data/raw-gdp-ppp-current-international-dollar.csv", header=1)

# %%
gdp.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Last Updated Date  \
# ...

# %%
import pandas as pd

# %%
gdp2 = pd.read_csv("/Users/tschoe/neuefische1/capstone/capstone_project/data/gdp-ppp-current-international-dollar-clean.csv")
#better version, discovered too late... 
gdp2
# Out:
#                      Country Name Country Code  Year       GDP_PPP
# 0                           Aruba          ABW  1990  1.447709e+09
# 1     Africa Eastern and Southern          AFE  1990  5.653495e+11
# 2                     Afghanistan          AFG  1990           NaN
# 3      Africa Western and Central          AFW  1990  3.544564e+11
# 4                          Angola          AGO  1990  3.885349e+10
# ...                           ...          ...   ...           ...
# 8241                       Kosovo          XKX  2020  2.021738e+10
# 8242                  Yemen, Rep.          YEM  2020           NaN
# 8243                 South Africa          ZAF  2020  7.923981e+11
# 8244                       Zambia          ZMB  2020  6.356455e+10
# 8245                     Zimbabwe          ZWE  2020  5.257540e+10
#
# [8246 rows x 4 columns]

# %%
energy_c = pd.read_csv("data/energy-consumption-by-source-and-region.csv")
energy_c
# Out:
#      iso_code     country  year  nuclear_consumption  coal_consumption  \
# 0         AGO      Angola  1990                  0.0               0.0
# 1         AGO      Angola  1991                  0.0               0.0
# 2         AGO      Angola  1992                  0.0               0.0
# 3         AGO      Angola  1993                  0.0               0.0
# 4         AGO      Angola  1994                  0.0               0.0
# ...       ...         ...   ...                  ...               ...
# 7170      NaN  Yugoslavia  2012                  NaN               NaN
# 7171      NaN  Yugoslavia  2013                  NaN               NaN
# 7172      NaN  Yugoslavia  2014                  NaN               NaN
# 7173      NaN  Yugoslavia  2015                  NaN               NaN
# 7174      NaN  Yugoslavia  2016                  NaN               NaN
#
#       hydro_consumption  oil_consumption  gas_consumption  wind_consumption  \
# ...

# %%
new= pd.read_csv("data/energy-consumption-by-source-and-region.csv")
new
# Out:
#      iso_code     country  year  nuclear_consumption  coal_consumption  \
# 0         AGO      Angola  1990                  0.0               0.0
# 1         AGO      Angola  1991                  0.0               0.0
# 2         AGO      Angola  1992                  0.0               0.0
# 3         AGO      Angola  1993                  0.0               0.0
# 4         AGO      Angola  1994                  0.0               0.0
# ...       ...         ...   ...                  ...               ...
# 7170      NaN  Yugoslavia  2012                  NaN               NaN
# 7171      NaN  Yugoslavia  2013                  NaN               NaN
# 7172      NaN  Yugoslavia  2014                  NaN               NaN
# 7173      NaN  Yugoslavia  2015                  NaN               NaN
# 7174      NaN  Yugoslavia  2016                  NaN               NaN
#
#       hydro_consumption  oil_consumption  gas_consumption  wind_consumption  \
# ...

# %%
gdp = pd.read_csv("data/gdp-ppp-current-international-dollar-clean.csv")
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8246 entries, 0 to 8245
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  8246 non-null   object
#  1   Country Code  8246 non-null   object
#  2   Year          8246 non-null   int64
#  3   GDP_PPP       7241 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 257.8+ KB

# %%
energy_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21669 entries, 0 to 21668
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   21667 non-null  object
#  1   iso_code                     19439 non-null  object
#  2   country                      21665 non-null  object
#  3   year                         21665 non-null  object
#  4   nuclear_consumption          8769 non-null   object
#  5   coal_consumption             10209 non-null  object
#  6   hydro_consumption            8769 non-null   object
#  7   oil_consumption              10209 non-null  object
#  8   gas_consumption              10209 non-null  object
#  9   wind_consumption             8769 non-null   object
#  10  solar_consumption            7472 non-null   object
#  11  other_renewable_consumption  8769 non-null   object
#  12  primary_energy_consumption   14363 non-null  object
# ...

# %%
cols= gdp.columns.tolist()

# %%
newcols=[]
for i in cols :
    x= i.lower()
    y= x.replace(" ","_")
    z= y.replace("-","_")
    newcols.append(z)
newcols
# Out:
# ['country_name', 'country_code', 'year', 'gdp_ppp']

# %%
gdp.columns= newcols
gdp.columns = gdp.columns.str.replace('country_code','iso_code')
gdp.head()
# Out:
#                   country_name iso_code  year       gdp_ppp
# 0                        Aruba      ABW  1990  1.447709e+09
# 1  Africa Eastern and Southern      AFE  1990  5.653495e+11
# 2                  Afghanistan      AFG  1990           NaN
# 3   Africa Western and Central      AFW  1990  3.544564e+11
# 4                       Angola      AGO  1990  3.885349e+10

# %%
#merge with
energy_c.head()
# Out:
#   iso_code country  year  nuclear_consumption  coal_consumption  \
# 0      AGO  Angola  1990                  0.0               0.0
# 1      AGO  Angola  1991                  0.0               0.0
# 2      AGO  Angola  1992                  0.0               0.0
# 3      AGO  Angola  1993                  0.0               0.0
# 4      AGO  Angola  1994                  0.0               0.0
#
#    hydro_consumption  oil_consumption  gas_consumption  wind_consumption  \
# 0           2.051429        15.325936         5.834961               0.0
# 1           2.042857        16.144753         6.142351               0.0
# 2           2.377143        16.129702         6.182138               0.0
# 3           2.517143        15.644819         6.073679               0.0
# 4           2.531429        15.469970         5.638678               0.0
#
#    solar_consumption  other_renewable_consumption  biofuel_consumption  \
# ...

# %%
energy_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7175 entries, 0 to 7174
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   iso_code                     6433 non-null   object
#  1   country                      7175 non-null   object
#  2   year                         7175 non-null   int64
#  3   nuclear_consumption          3787 non-null   float64
#  4   coal_consumption             4267 non-null   float64
#  5   hydro_consumption            3787 non-null   float64
#  6   oil_consumption              4267 non-null   float64
#  7   gas_consumption              4267 non-null   float64
#  8   wind_consumption             3787 non-null   float64
#  9   solar_consumption            2490 non-null   float64
#  10  other_renewable_consumption  3787 non-null   float64
#  11  biofuel_consumption          4308 non-null   float64
# ...

# %%
ec_gdp= energy_c.merge(gdp, on=["year","iso_code"],how="inner")

# %%
merged.year = merged.year.astype(int)

# %%
ec_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6017 entries, 0 to 6016
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   iso_code                     6017 non-null   object
#  1   country                      6017 non-null   object
#  2   year                         6017 non-null   int64
#  3   nuclear_consumption          3637 non-null   float64
#  4   coal_consumption             3637 non-null   float64
#  5   hydro_consumption            3637 non-null   float64
#  6   oil_consumption              3637 non-null   float64
#  7   gas_consumption              3637 non-null   float64
#  8   wind_consumption             3637 non-null   float64
#  9   solar_consumption            2340 non-null   float64
#  10  other_renewable_consumption  3637 non-null   float64
#  11  biofuel_consumption          4158 non-null   float64
# ...

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8246 entries, 0 to 8245
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_name  8246 non-null   object
#  1   iso_code      8246 non-null   object
#  2   year          8246 non-null   int64
#  3   gdp_ppp       7241 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 257.8+ KB

# %%
pec = pd.read_csv("data/total_primary_energy_consumption.csv")
pec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7244 entries, 0 to 7243
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   iso_code                    6502 non-null   object
#  1   country                     7244 non-null   object
#  2   year                        7244 non-null   int64
#  3   primary_energy_consumption  6661 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 226.5+ KB

# %%
pec_gdp.drop(columns="country_name",axis=1,inplace=True)
pec_gdp
# Out:
#      iso_code      country  year  primary_energy_consumption       gdp_ppp
# 0         AFG  Afghanistan  1990                      31.627           NaN
# 1         AFG  Afghanistan  1991                      13.651           NaN
# 2         AFG  Afghanistan  1992                       8.961           NaN
# 3         AFG  Afghanistan  1993                       8.935           NaN
# 4         AFG  Afghanistan  1994                       8.617           NaN
# ...       ...          ...   ...                         ...           ...
# 6081      ZWE     Zimbabwe  2015                      55.642  3.701644e+10
# 6082      ZWE     Zimbabwe  2016                      47.500  3.937571e+10
# 6083      ZWE     Zimbabwe  2017                         NaN  5.403704e+10
# 6084      ZWE     Zimbabwe  2018                         NaN  5.800391e+10
# 6085      ZWE     Zimbabwe  2019                         NaN  5.541185e+10
#
# [6086 rows x 5 columns]

# %%
data_90 = pec_gdp[pec_gdp["year"]==1990]
data_00 = pec_gdp[pec_gdp["year"]==2000]
data_10 = pec_gdp[pec_gdp["year"]==2010]
data_19 = pec_gdp[pec_gdp["year"]==2019]
data_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197 entries, 29 to 6085
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   iso_code                    197 non-null    object
#  1   country                     197 non-null    object
#  2   year                        197 non-null    int64
#  3   primary_energy_consumption  78 non-null     float64
#  4   gdp_ppp                     181 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 9.2+ KB

# %%
sns.scatterplot(data=data_90, x="gdp_ppp",y="primary_energy_consumption")
# Out:
# <AxesSubplot:xlabel='gdp_ppp', ylabel='primary_energy_consumption'>

# %%
data_90.sort_values(by="primary_energy_consumption",ascending=False)
# Out:
#      iso_code                   country  year  primary_energy_consumption  \
# 5783      USA             United States  1990                   22498.158
# 4534      RUS                    Russia  1990                   10039.125
# 1179      CHN                     China  1990                    7972.531
# 2831      JPN                     Japan  1990                    5168.547
# 2104      DEU                   Germany  1990                    4179.821
# ...       ...                       ...   ...                         ...
# 786       VGB    British Virgin Islands  1990                       0.194
# 2953      KIR                  Kiribati  1990                       0.076
# 5631      TCA  Turks and Caicos Islands  1990                       0.000
# 4087      MNP  Northern Mariana Islands  1990                       0.000
# 4805      SRB                    Serbia  1990                         NaN
#
#            gdp_ppp
# 5783  5.963144e+12
# 4534  1.187862e+12
# ...

# %%
import numpy as np 
data_90.gdp = data_90.gdp.replace("..",np.nan)
data_00.gdp = data_00.gdp.replace("..",np.nan)
data_10.gdp = data_10.gdp.replace("..",np.nan)
data_19.gdp = data_19.gdp.replace("..",np.nan)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data_90
# Out:
#      iso_code         country  year  primary_energy_consumption       gdp_ppp
# 0         AFG     Afghanistan  1990                      31.627           NaN
# 30        ALB         Albania  1990                      40.289  8.374479e+09
# 60        DZA         Algeria  1990                     314.950  1.780476e+11
# 90        ASM  American Samoa  1990                       2.408           NaN
# 120       AGO          Angola  1990                      23.212  3.885349e+10
# ...       ...             ...   ...                         ...           ...
# 5935      VEN       Venezuela  1990                     596.927  1.883723e+11
# 5965      VNM         Vietnam  1990                      75.844  6.235185e+10
# 5996      YEM           Yemen  1990                      47.102  2.420827e+10
# 6026      ZMB          Zambia  1990                      32.965  1.185256e+10
# 6056      ZWE        Zimbabwe  1990                      58.829  1.849260e+10
#
# [192 rows x 5 columns]

# %%
data_90.gdp = data_90.gdp.astype(float)
data_00.gdp = data_00.gdp.astype(float)
data_10.gdp = data_10.gdp.astype(float)
data_19.gdp = data_19.gdp.astype(float)

# %%
fig = plt.figure(figsize=(12,8))
plt.scatter(data=data_90,y="primary_energy_consumption",s="primary_energy_consumption", label="1990",x="gdp_ppp", color="green")
plt.scatter(data=data_00,y="primary_energy_consumption",s="primary_energy_consumption",label="2000",x="gdp_ppp", color="orange")
plt.scatter(data=data_10,y="primary_energy_consumption",s="primary_energy_consumption",label="2010",x="gdp_ppp", color="red")
plt.scatter(data=data_19,y="primary_energy_consumption",label="2019",x="gdp_ppp")

plt.xscale("log")
plt.yscale("log")
plt.title("Primary Energy Consumption and GDP")
plt.ylabel("Primary Energy Consumption in TWH")
plt.xlabel("GDP (in PPP $)")


#alpha?!
# add label for years!!!
# Out:
# Text(0.5, 0, 'GDP (in PPP $)')

# %%
data_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 394 entries, 58 to 12171
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   iso_code                     394 non-null    object
#  1   country                      394 non-null    object
#  2   year                         394 non-null    int64
#  3   nuclear_consumption          156 non-null    object
#  4   coal_consumption             156 non-null    object
#  5   hydro_consumption            156 non-null    object
#  6   oil_consumption              156 non-null    object
#  7   gas_consumption              156 non-null    object
#  8   wind_consumption             156 non-null    object
#  9   solar_consumption            156 non-null    object
#  10  other_renewable_consumption  156 non-null    object
#  11  primary_energy_consumption   191 non-null    float64
#  12  energy_per_capita            156 non-null    object
# ...

# %%
data_19.sort_values(by="primary_energy_consumption").head(20)
# Out:
#       iso_code        country  year nuclear_consumption coal_consumption  \
# 6443       LBY          Libya  2019                 NaN              NaN
# 8049       NGA        Nigeria  2019                 NaN              NaN
# 7929       NIC      Nicaragua  2019                 NaN              NaN
# 7867       NZL    New Zealand  2019                 0.0           17.235
# 7807       NCL  New Caledonia  2019                 NaN              NaN
# 7505       MMR        Myanmar  2019                 NaN              NaN
# 7445       MOZ     Mozambique  2019                 NaN              NaN
# 7385       MAR        Morocco  2019                 0.0           77.515
# 7281       MNG       Mongolia  2019                 NaN              NaN
# 6807       MYS       Malaysia  2019                 0.0          249.354
# 6687       MDG     Madagascar  2019                 NaN              NaN
# 6565       LUX     Luxembourg  2019                 0.0             0.65
# ...

# %%
# not only for 2019, but from 1990 on:

merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12172 entries, 0 to 12171
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   iso_code                     12172 non-null  object
#  1   country                      12172 non-null  object
#  2   year                         12172 non-null  int64
#  3   nuclear_consumption          4680 non-null   object
#  4   coal_consumption             4680 non-null   object
#  5   hydro_consumption            4680 non-null   object
#  6   oil_consumption              4680 non-null   object
#  7   gas_consumption              4680 non-null   object
#  8   wind_consumption             4680 non-null   object
#  9   solar_consumption            4680 non-null   object
#  10  other_renewable_consumption  4680 non-null   object
#  11  primary_energy_consumption   8881 non-null   float64
#  12  energy_per_capita            7952 non-null   object
# ...

# %%
merged.gdp = merged.gdp.replace("..",np.nan)

# %%
merged.columns
# Out:
# Index(['iso_code', 'country', 'year', 'nuclear_consumption',
#        'coal_consumption', 'hydro_consumption', 'oil_consumption',
#        'gas_consumption', 'wind_consumption', 'solar_consumption',
#        'other_renewable_consumption', 'primary_energy_consumption',
#        'energy_per_capita', 'biofuel_consumption', 'low_carbon_consumption',
#        'renewables_consumption', 'country_name', 'gdp'],
#       dtype='object')

# %%
merged.gdp = merged.gdp.astype(float)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=merged[merged["country"]=="China"], legend=False,x="primary_energy_consumption",marker="s",size=area,color="green",y="gdp")
sns.scatterplot(data=merged[merged["country"]=="United States"], legend=False,x="primary_energy_consumption",size="renewables_consumption",y="gdp",hue="year")
sns.scatterplot(data=merged[merged["country"]!="China"], x="primary_energy_consumption",y="gdp",hue="year")
plt.title("Primary Energy Consumption per GDP")
plt.ticklabel_format(useOffset=False, style='plain')
plt.xscale("log")
plt.yscale("log")

# %%
merged.columns
# Out:
# Index(['iso_code', 'country', 'year', 'nuclear_consumption',
#        'coal_consumption', 'hydro_consumption', 'oil_consumption',
#        'gas_consumption', 'wind_consumption', 'solar_consumption',
#        'other_renewable_consumption', 'primary_energy_consumption',
#        'energy_per_capita', 'biofuel_consumption', 'low_carbon_consumption',
#        'renewables_consumption', 'country_name', 'gdp', 'fossil_consumption'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=merged[merged["country"]=="China"], legend=False,x="fossil_consumption",marker="s",size=area,color="green",y="gdp")
sns.scatterplot(data=merged[merged["country"]=="Germany"], legend=False,x="fossil_consumption",size="renewables_consumption",y="gdp",hue="year")
sns.scatterplot(data=merged[merged["country"]!="China"], x="fossil_consumption",y="gdp",hue="year")
plt.title("Fossil Energy Consumption per GDP")
plt.xscale("log")
plt.yscale("log")

# %%
merged= merged[merged.year < 2020]

# %%
#tableau cant sse float data for some reason...
merged.gdp = merged.gdp.astype(str).str.split(".",expand=True)[0].astype(float)
merged.loc[country=="China"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/kh/ks_sxbc53y3dz6m5fbs40y480000gn/T/ipykernel_40918/3452943527.py in <module>
#       1 #tableau cant sse float data for some reason...
#       2 merged.gdp = merged.gdp.astype(str).str.split(".",expand=True)[0].astype(float)
# ----> 3 merged.loc[country=="China"]
#
# NameError: name 'country' is not defined

# %%
merged[merged['country']=="China"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 1142 to 1170
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   iso_code                     29 non-null     object
#  1   country                      29 non-null     object
#  2   year                         29 non-null     int64
#  3   nuclear_consumption          29 non-null     float64
#  4   coal_consumption             29 non-null     float64
#  5   hydro_consumption            29 non-null     float64
#  6   oil_consumption              29 non-null     float64
#  7   gas_consumption              29 non-null     float64
#  8   wind_consumption             29 non-null     float64
#  9   solar_consumption            29 non-null     float64
#  10  other_renewable_consumption  29 non-null     float64
#  11  primary_energy_consumption   29 non-null     float64
# ...

# %%
merged.to_csv("GDP_energy.csv", index=False)
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5825 entries, 0 to 5893
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   iso_code                     5825 non-null   object
#  1   country                      5825 non-null   object
#  2   year                         5825 non-null   int64
#  3   nuclear_consumption          2262 non-null   float64
#  4   coal_consumption             2262 non-null   float64
#  5   hydro_consumption            2262 non-null   float64
#  6   oil_consumption              2262 non-null   float64
#  7   gas_consumption              2262 non-null   float64
#  8   wind_consumption             2262 non-null   float64
#  9   solar_consumption            2262 non-null   float64
#  10  other_renewable_consumption  2262 non-null   float64
#  11  primary_energy_consumption   5448 non-null   float64
# ...

# %%
# twh stunden.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12172 entries, 0 to 12171
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   iso_code                     12172 non-null  object
#  1   country                      12172 non-null  object
#  2   year                         12172 non-null  int64
#  3   nuclear_consumption          4680 non-null   object
#  4   coal_consumption             4680 non-null   object
#  5   hydro_consumption            4680 non-null   object
#  6   oil_consumption              4680 non-null   object
#  7   gas_consumption              4680 non-null   object
#  8   wind_consumption             4680 non-null   object
#  9   solar_consumption            4680 non-null   object
#  10  other_renewable_consumption  4680 non-null   object
#  11  primary_energy_consumption   8881 non-null   float64
#  12  energy_per_capita            7952 non-null   object
# ...

# %%
sns.lineplot(x="year",y="fossil_consumption",hue="country", legend= False ,data=merged)
# Out:
# <AxesSubplot:xlabel='year', ylabel='fossil_consumption'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-dark')

# %%
sns.lineplot(x="year",y="fossil_consumption", label="China",data=merged[merged.country=="China"])
sns.lineplot(x="year",y="fossil_consumption", label="United States",data=merged[merged.country=="United States"])
sns.lineplot(x="year",y="fossil_consumption",hue="country", legend= False ,data=merged[~merged.country.isin(["China","United States"])])
plt.title("Fossil Energy Consumption", size=20)
plt.ylabel("Fossil Energy Consumtion in TWH")
plt.legend()

# %%
#how does it look like for the whole world?
merged.head()
# Out:
#   iso_code      country  year  nuclear_consumption  coal_consumption  \
# 0      AFG  Afghanistan  1990                  NaN               NaN
# 1      AFG  Afghanistan  1991                  NaN               NaN
# 2      AFG  Afghanistan  1992                  NaN               NaN
# 3      AFG  Afghanistan  1993                  NaN               NaN
# 4      AFG  Afghanistan  1994                  NaN               NaN
#
#    hydro_consumption  oil_consumption  gas_consumption  wind_consumption  \
# 0                NaN              NaN              NaN               NaN
# 1                NaN              NaN              NaN               NaN
# 2                NaN              NaN              NaN               NaN
# 3                NaN              NaN              NaN               NaN
# 4                NaN              NaN              NaN               NaN
#
#    solar_consumption  other_renewable_consumption  primary_energy_consumption  \
# ...

# %%
total_ec = pd.read_csv("data/total_primary_energy_consumption.csv")
total_ec.sort_values(by="primary_energy_consumption", ascending=False).head() # ok, we need for the entire world...

#would be also available for regions.
# Out:
#       Unnamed: 0  iso_code country  year  primary_energy_consumption
# 7125        7125  OWID_WRL   World  2019                  162194.290
# 7124        7124  OWID_WRL   World  2018                  160063.686
# 7123        7123  OWID_WRL   World  2017                  155672.784
# 7122        7122  OWID_WRL   World  2016                  152944.938
# 7121        7121  OWID_WRL   World  2015                  150882.037

# %%
world_pec=total_ec[total_ec.country=="World"]

# %%
total_ec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7244 entries, 0 to 7243
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  7244 non-null   int64
#  1   iso_code                    6502 non-null   object
#  2   country                     7244 non-null   object
#  3   year                        7244 non-null   int64
#  4   primary_energy_consumption  6661 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 283.1+ KB

# %%
recent_gdp
# Out:
#                                      country_name iso_code  year  \
# 8130                                  Afghanistan      AFG  1990
# 8131                                      Albania      ALB  1990
# 8132                                      Algeria      DZA  1990
# 8133                               American Samoa      ASM  1990
# 8134                                      Andorra      AND  1990
# ...                                           ...      ...   ...
# 16521                          Sub-Saharan Africa      SSF  2020
# 16522  Sub-Saharan Africa (excluding high income)      SSA  2020
# 16523   Sub-Saharan Africa (IDA & IBRD countries)      TSS  2020
# 16524                         Upper middle income      UMC  2020
# 16525                                       World      WLD  2020
#
#                     gdp
# 8130                 ..
# 8131   8374478544.59225
# 8132    178047567922.31
# 8133                 ..
# 8134                 ..
# ...                 ...
# ...

# %%
world_gdp = recent_gdp[recent_gdp.country_name=="World"]
world_gdp
# Out:
#       country_name iso_code  year               gdp
# 8395         World      WLD  1990  29347220680753.8
# 8666         World      WLD  1991    30942360752314
# 8937         World      WLD  1992  32353421066062.4
# 9208         World      WLD  1993  33759271750280.1
# 9479         World      WLD  1994  35568114475179.1
# 9750         World      WLD  1995  37558802917360.9
# 10021        World      WLD  1996  39798436638464.3
# 10292        World      WLD  1997  42074908311213.7
# 10563        World      WLD  1998  43478769612725.4
# 10834        World      WLD  1999  45615641718639.6
# 11105        World      WLD  2000  49016733287074.6
# 11376        World      WLD  2001  51363251894047.7
# 11647        World      WLD  2002  53830430406839.3
# 11918        World      WLD  2003  56846210144584.3
# 12189        World      WLD  2004  61448937395132.2
# 12460        World      WLD  2005  66187283958714.6
# 12731        World      WLD  2006    72463642016677
# ...

# %%
merged
# Out:
#      iso_code      country  year  nuclear_consumption  coal_consumption  \
# 0         AFG  Afghanistan  1990                  NaN               NaN
# 1         AFG  Afghanistan  1991                  NaN               NaN
# 2         AFG  Afghanistan  1992                  NaN               NaN
# 3         AFG  Afghanistan  1993                  NaN               NaN
# 4         AFG  Afghanistan  1994                  NaN               NaN
# ...       ...          ...   ...                  ...               ...
# 6081      ZWE     Zimbabwe  2015                  NaN               NaN
# 6082      ZWE     Zimbabwe  2016                  NaN               NaN
# 6083      ZWE     Zimbabwe  2017                  NaN               NaN
# 6084      ZWE     Zimbabwe  2018                  NaN               NaN
# 6085      ZWE     Zimbabwe  2019                  NaN               NaN
#
#       hydro_consumption  oil_consumption  gas_consumption  wind_consumption  \
# ...

# %%
world_gdp.gdp= world_gdp.gdp.astype(float)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
fig, ax1 = plt.subplots(figsize=(12,5))
fig.suptitle("World GDP vs. World PEC")
ax2 = ax1.twinx()
ax1.plot(world_pec.year,world_pec.primary_energy_consumption,c="red")
ax1.set(xlabel="year")
ax1.set_ylabel("PEC in TwH",color="red", fontsize=14)
ax1.tick_params(axis="y", labelcolor="red")


ax2.plot(world_gdp.year,world_gdp["gdp"],c="blue")
ax2.tick_params(axis="y", labelcolor="blue")
ax2.set_ylabel("GDP (in $ PPP)",color="blue", fontsize=14)
plt.ticklabel_format(style='plain')    # to prevent scientific notation.
ax2.set_yticks(ticks=[])

# %%
world_pec[world_pec.year==2019]
# Out:
#       Unnamed: 0  iso_code country  year  primary_energy_consumption
# 7125        7125  OWID_WRL   World  2019                   162194.29

# %%
fig, ax1 = plt.subplots(figsize=(12,5))
fig.suptitle("World GDP vs. World PEC")
ax2 = ax1.twinx()
ax1.plot(world_pec.year,world_pec.primary_energy_consumption,c="red")
ax1.set(xlabel="year")
ax1.set_ylabel("PEC in TwH",color="red", fontsize=14)
ax1.tick_params(axis="y", labelcolor="red")


ax2.plot(world_gdp.year,world_gdp["gdp"],c="blue")
ax2.tick_params(axis="y", labelcolor="blue")
ax2.set_ylabel("GDP (in $ PPP)",color="blue", fontsize=14)

# %%
fig = plt.figure(figsize=(12,8))
plt.scatter(data=data_90,y="primary_energy_consumption",s="primary_energy_consumption", label="1990",x="gdp", color="green")
plt.scatter(data=data_00,y="primary_energy_consumption",s="primary_energy_consumption",label="2000",x="gdp", color="orange")
plt.scatter(data=data_10,y="primary_energy_consumption",s="primary_energy_consumption",label="2010",x="gdp", color="red")
plt.scatter(data=data_19,y="primary_energy_consumption",s="primary_energy_consumption",label="2019",x="gdp")
plt.xscale("log")
plt.yscale("log")
plt.title("Primary Energy Consumption and GDP")
plt.ylabel("Primary Energy Consumption in TWH")
plt.xlabel("GDP (in PPP $)")
plt.



# add label for years!!!
# Out:
# Text(0.5, 0, 'GDP (in PPP $)')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=merged[merged["country"]=="China"], legend=False,x="primary_energy_consumption",marker="s",size=area,color="green",y="gdp")
sns.scatterplot(data=merged[merged["country"]=="United States"], legend=False,x="primary_energy_consumption",size="renewables_consumption",y="gdp",hue="year")
sns.scatterplot(data=merged[merged["country"]!="China"], x="primary_energy_consumption",y="gdp",hue="year")
plt.title("Primary Energy Consumption per GDP")
plt.ticklabel_format(useOffset=False, style='plain')
plt.xscale("log")
plt.yscale("log")

# %%
merged[merged.year==]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=merged[merged["country"]=="China"], legend=False,x="fossil_consumption",marker="s",size=area,color="green",y="gdp")
sns.scatterplot(data=merged[merged["country"]=="Germany"], legend=False,x="fossil_consumption",size="renewables_consumption",y="gdp",hue="year")
sns.scatterplot(data=merged[merged["country"]!="China"], x="fossil_consumption",y="gdp",hue="year")
plt.title("Fossil Energy Consumption per GDP")
plt.xscale("log")
plt.yscale("log")

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x="year",y="fossil_consumption", label="China",data=merged[merged.country=="China"])
sns.lineplot(x="year",y="fossil_consumption", label="United States",data=merged[merged.country=="United States"])
sns.lineplot(x="year",y="fossil_consumption",label="Germany",data=merged[merged.country=="Germany"])

sns.lineplot(x="year",y="fossil_consumption",hue="country", legend= False ,data=merged[~merged.country.isin(["China","United States"])])
plt.title("Fossil Energy Consumption", size=20)
plt.ylabel("Fossil Energy Consumtion in TWH")
plt.legend()

# %%
merged["fossil_consumption_per_unit_of_gdp"] = merged["fossil_consumption"]/merged["gdp"]

# %%
fig = plt.figure(figsize=(12,8))
sns.lineplot(data=merged[merged.country=="Germany"], x="year",y="fossil_consumption_per_unit_of_gdp")
sns.lineplot(data=merged, x="year",y="fossil_consumption_per_unit_of_gdp",hue="country", legend=False)
# Out:
# <AxesSubplot:xlabel='year', ylabel='fossil_consumption_per_unit_of_gdp'>

# %%
# energy efficiency: PEC/GDP
