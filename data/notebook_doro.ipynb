# %%
import pandas as pd
import zipfile as zip
import matplotlib.pyplot as plt 
import seaborn as sn

# Read in owid total
owid_total = pd.read_csv('/Users/dorotheakirves/neuefische/capstone_project/data/raw-owid-energy-data.csv')

# %% [markdown]
# # GDP

# %%
# Read in GDP Data
gdp_ppp = pd.read_csv("/Users/dorotheakirves/neuefische/capstone_project/data/raw-gdp-ppp-current-international-dollar.csv", skiprows=4)

# %%
# Keep only country code, country name and GDP
gdp_ppp = gdp_ppp.drop(['Indicator Code', 'Indicator Name'], axis=1)
gdp_ppp.head()
# Out:
#                   Country Name Country Code  1960  1961  1962  1963  1964  \
# 0                        Aruba          ABW   NaN   NaN   NaN   NaN   NaN
# 1  Africa Eastern and Southern          AFE   NaN   NaN   NaN   NaN   NaN
# 2                  Afghanistan          AFG   NaN   NaN   NaN   NaN   NaN
# 3   Africa Western and Central          AFW   NaN   NaN   NaN   NaN   NaN
# 4                       Angola          AGO   NaN   NaN   NaN   NaN   NaN
#
#    1965  1966  1967  ...          2012          2013          2014  \
# 0   NaN   NaN   NaN  ...  3.442856e+09  3.799467e+09  3.816822e+09
# 1   NaN   NaN   NaN  ...  1.772679e+12  1.893539e+12  2.025402e+12
# 2   NaN   NaN   NaN  ...  5.966700e+10  6.503984e+10  6.905834e+10
# 3   NaN   NaN   NaN  ...  1.396677e+12  1.526772e+12  1.645122e+12
# 4   NaN   NaN   NaN  ...  1.861242e+11  1.998656e+11  2.203648e+11
#
#            2015          2016          2017          2018          2019  \
# 0  3.893071e+09  3.941354e+09  4.098240e+09           NaN           NaN
# 1  2.098286e+12  2.212573e+12  2.319151e+12  2.438518e+12  2.536280e+12
# 2  7.183170e+10  7.009796e+10  7.471192e+10  7.741557e+10  8.187980e+10
# 3  1.662297e+12  1.678674e+12  1.744087e+12  1.841811e+12  1.937451e+12
# 4  2.046036e+11  2.048747e+11  2.179873e+11  2.187486e+11  2.212628e+11
#
#            2020  Unnamed: 65
# 0           NaN          NaN
# 1  2.495345e+12          NaN
# 2  8.091834e+10          NaN
# 3  1.946297e+12          NaN
# 4  2.118373e+11          NaN
#
# [5 rows x 64 columns]

# %%
# Years in rows
gdp_ppp = gdp_ppp.melt(id_vars=["Country Name", "Country Code"], 
        var_name="Year", 
        value_name="GDP_PPP")
gdp_ppp.head()
# Out:
#                   Country Name Country Code  Year  GDP_PPP
# 0                        Aruba          ABW  1960      NaN
# 1  Africa Eastern and Southern          AFE  1960      NaN
# 2                  Afghanistan          AFG  1960      NaN
# 3   Africa Western and Central          AFW  1960      NaN
# 4                       Angola          AGO  1960      NaN

# %%
# Convert year into numeric, drop rows before 1990, reset index
gdp_ppp["Year"] = pd.to_numeric(gdp_ppp["Year"], errors='coerce')
gdp_ppp = gdp_ppp.drop(gdp_ppp[gdp_ppp.Year < 1990].index)
gdp_ppp = gdp_ppp.reset_index()
gdp_ppp = gdp_ppp.drop(['index'], axis=1)

# %%
gdp_ppp.head()
# Out:
#                   Country Name Country Code    Year       GDP_PPP
# 0                        Aruba          ABW  1990.0  1.447709e+09
# 1  Africa Eastern and Southern          AFE  1990.0  5.653495e+11
# 2                  Afghanistan          AFG  1990.0           NaN
# 3   Africa Western and Central          AFW  1990.0  3.544564e+11
# 4                       Angola          AGO  1990.0  3.885349e+10

# %%
# Store in csv again for tableau
gdp_ppp.to_csv('/Users/dorotheakirves/neuefische/capstone_project/data/gdp-ppp-current-international-dollar-clean.csv')

# %% [markdown]
# # Country Codes

# %%
# Read in country codes in Stata
country_codes = pd.read_stata('/Users/dorotheakirves/neuefische/capstone_project/data/location.dta')
country_codes.head()
# Out:
#   location_id location_code location_name_short_en    level  parent_id
# 0           0           ABW                  Aruba  country      356.0
# 1           1           AFG            Afghanistan  country      353.0
# 2           2           AGO                 Angola  country      352.0
# 3           3           AIA               Anguilla  country      356.0
# 4           4           ALB                Albania  country      355.0

# %%
# Store country codes in csv for Tableau
country_codes.to_csv('/Users/dorotheakirves/neuefische/capstone_project/data/location.csv')

# %% [markdown]
# # OWID Total - Population

# %%
# Read in owid total
owid_total = pd.read_csv('/Users/dorotheakirves/neuefische/capstone_project/data/raw-owid-energy-data.csv')

# %%
# Keep only Country code, country name, year and population
population = owid_total[["iso_code", "country", "year","population"]]

# %%
# Drop rows before 1990
population = population.drop(population[population.year < 1990].index)
population = population.reset_index()
population = population.drop(['index'], axis=1)

# %%
# Store population in csv for Tableau
population.to_csv('/Users/dorotheakirves/neuefische/capstone_project/data/population.csv')

# %% [markdown]
# # OWID Total - Energy consumption

# %%
# Keep only Country code, country name, year and and consumption by source from owid_total
prim_en_cons = owid_total[['iso_code', 'country', 'year', 'nuclear_consumption', 'coal_consumption', 'hydro_consumption', 'oil_consumption', 'gas_consumption', 'wind_consumption', 'solar_consumption', 'other_renewable_consumption', 'primary_energy_consumption', 'energy_per_capita', 'biofuel_consumption', 'low_carbon_consumption', 'renewables_consumption']]

# %%
# Drop rows before 1990
prim_en_cons = prim_en_cons.drop(prim_en_cons[prim_en_cons.year < 1990].index)
prim_en_cons = prim_en_cons.reset_index()
prim_en_cons = prim_en_cons.drop(['index'], axis=1)

# %%
# Store energy consumption in csv for Tableau
prim_en_cons.to_csv('/Users/dorotheakirves/neuefische/capstone_project/data/energy-consumption-by-source-and-region.csv')

# %% [markdown]
# # Create Data for Africa

# %%
# Check for data in random African country
prim_en_cons.loc[(prim_en_cons["country"] == "Zambia") & (prim_en_cons["year"] > 2010)]
# Out:
#       country  nuclear_consumption  coal_consumption  hydro_consumption  \
# 17341  Zambia                  NaN               NaN                NaN
# 17342  Zambia                  NaN               NaN                NaN
# 17343  Zambia                  NaN               NaN                NaN
# 17344  Zambia                  NaN               NaN                NaN
# 17345  Zambia                  NaN               NaN                NaN
# 17346  Zambia                  NaN               NaN                NaN
# 17347  Zambia                  NaN               NaN                NaN
# 17348  Zambia                  NaN               NaN                NaN
# 17349  Zambia                  NaN               NaN                NaN
#
#        oil_consumption  gas_consumption  wind_consumption  year  \
# 17341              NaN              NaN               NaN  2011
# 17342              NaN              NaN               NaN  2012
# 17343              NaN              NaN               NaN  2013
# 17344              NaN              NaN               NaN  2014
# 17345              NaN              NaN               NaN  2015
# 17346              NaN              NaN               NaN  2016
# 17347              NaN              NaN               NaN  2017
# 17348              NaN              NaN               NaN  2018
# 17349              NaN              NaN               NaN  2019
#
#        solar_consumption  other_renewable_consumption  \
# 17341                NaN                          NaN
# 17342                NaN                          NaN
# 17343                NaN                          NaN
# 17344                NaN                          NaN
# 17345                NaN                          NaN
# 17346                NaN                          NaN
# 17347                NaN                          NaN
# 17348                NaN                          NaN
# 17349                NaN                          NaN
#
#        primary_energy_consumption  energy_per_capita  biofuel_consumption  \
# 17341                      42.616           3039.025                  0.0
# 17342                      47.439           3279.589                  0.0
# 17343                      50.378           3374.976                  0.0
# 17344                      54.348           3529.102                  0.0
# 17345                      51.996           3274.540                  0.0
# 17346                      46.347           2832.411                  0.0
# 17347                         NaN                NaN                  0.0
# 17348                         NaN                NaN                  0.0
# 17349                         NaN                NaN                  0.0
#
#       iso_code  low_carbon_consumption  renewables_consumption
# 17341      ZMB                     NaN                     NaN
# 17342      ZMB                     NaN                     NaN
# 17343      ZMB                     NaN                     NaN
# 17344      ZMB                     NaN                     NaN
# 17345      ZMB                     NaN                     NaN
# 17346      ZMB                     NaN                     NaN
# 17347      ZMB                     NaN                     NaN
# 17348      ZMB                     NaN                     NaN
# 17349      ZMB                     NaN                     NaN

# %%
# generate list of all Africa countries
africa = pd.read_csv('/Users/dorotheakirves/neuefische/Capstone/Unbenannte Tabelle - Tabellenblatt1.csv')
#africa = africa['country'].tolist()
africa.to_csv('/Users/dorotheakirves/neuefische/capstone_project/data/countries_in_africa.csv')

# %%
# Create code for finding nulls
sources = ['nuclear_consumption', 'coal_consumption', 'hydro_consumption', 'oil_consumption', 'gas_consumption', 'wind_consumption', 'solar_consumption', 'other_renewable_consumption', 'low_carbon_consumption', 'renewables_consumption']
code = ''
for i in sources:
    text = f'(prim_en_cons["{i}"].isnull()) & '
    code = code+text
code
# Out:
# '(prim_en_cons["nuclear_consumption"].isnull()) & (prim_en_cons["coal_consumption"].isnull()) & (prim_en_cons["hydro_consumption"].isnull()) & (prim_en_cons["oil_consumption"].isnull()) & (prim_en_cons["gas_consumption"].isnull()) & (prim_en_cons["wind_consumption"].isnull()) & (prim_en_cons["solar_consumption"].isnull()) & (prim_en_cons["other_renewable_consumption"].isnull()) & (prim_en_cons["low_carbon_consumption"].isnull()) & (prim_en_cons["renewables_consumption"].isnull()) & '

# %%
# Identify countries with null on sources
null_sources = prim_en_cons.loc[(prim_en_cons["nuclear_consumption"].isnull()) & (prim_en_cons["coal_consumption"].isnull()) & (prim_en_cons["hydro_consumption"].isnull()) & (prim_en_cons["oil_consumption"].isnull()) & (prim_en_cons["gas_consumption"].isnull()) & (prim_en_cons["wind_consumption"].isnull()) & (prim_en_cons["solar_consumption"].isnull()) & (prim_en_cons["other_renewable_consumption"].isnull()) & (prim_en_cons["low_carbon_consumption"].isnull()) & (prim_en_cons["renewables_consumption"].isnull()) & (prim_en_cons["year"] > 2000)]
kenya = null_sources.loc[(null_sources["country"] == "Kenya")]
kenya.head(n = 50)
#null_sources_countries = null_sources['country'].unique().tolist()
#'Kenya' in null_sources_countries
# Out:
#      iso_code country  year  nuclear_consumption  coal_consumption  \
# 3304      KEN   Kenya  2001                  NaN               NaN
# 3305      KEN   Kenya  2002                  NaN               NaN
# 3306      KEN   Kenya  2003                  NaN               NaN
# 3307      KEN   Kenya  2004                  NaN               NaN
# 3308      KEN   Kenya  2005                  NaN               NaN
# 3309      KEN   Kenya  2006                  NaN               NaN
# 3310      KEN   Kenya  2007                  NaN               NaN
# 3311      KEN   Kenya  2008                  NaN               NaN
# 3312      KEN   Kenya  2009                  NaN               NaN
# 3313      KEN   Kenya  2010                  NaN               NaN
# 3314      KEN   Kenya  2011                  NaN               NaN
# 3315      KEN   Kenya  2012                  NaN               NaN
# 3316      KEN   Kenya  2013                  NaN               NaN
# 3317      KEN   Kenya  2014                  NaN               NaN
# 3318      KEN   Kenya  2015                  NaN               NaN
# 3319      KEN   Kenya  2016                  NaN               NaN
# 3320      KEN   Kenya  2017                  NaN               NaN
# 3321      KEN   Kenya  2018                  NaN               NaN
# 3322      KEN   Kenya  2019                  NaN               NaN
#
#       hydro_consumption  oil_consumption  gas_consumption  wind_consumption  \
# 3304                NaN              NaN              NaN               NaN
# 3305                NaN              NaN              NaN               NaN
# 3306                NaN              NaN              NaN               NaN
# 3307                NaN              NaN              NaN               NaN
# 3308                NaN              NaN              NaN               NaN
# 3309                NaN              NaN              NaN               NaN
# 3310                NaN              NaN              NaN               NaN
# 3311                NaN              NaN              NaN               NaN
# 3312                NaN              NaN              NaN               NaN
# 3313                NaN              NaN              NaN               NaN
# 3314                NaN              NaN              NaN               NaN
# 3315                NaN              NaN              NaN               NaN
# 3316                NaN              NaN              NaN               NaN
# 3317                NaN              NaN              NaN               NaN
# 3318                NaN              NaN              NaN               NaN
# 3319                NaN              NaN              NaN               NaN
# 3320                NaN              NaN              NaN               NaN
# 3321                NaN              NaN              NaN               NaN
# 3322                NaN              NaN              NaN               NaN
#
#       solar_consumption  other_renewable_consumption  \
# 3304                NaN                          NaN
# 3305                NaN                          NaN
# 3306                NaN                          NaN
# 3307                NaN                          NaN
# 3308                NaN                          NaN
# 3309                NaN                          NaN
# 3310                NaN                          NaN
# 3311                NaN                          NaN
# 3312                NaN                          NaN
# 3313                NaN                          NaN
# 3314                NaN                          NaN
# 3315                NaN                          NaN
# 3316                NaN                          NaN
# 3317                NaN                          NaN
# 3318                NaN                          NaN
# 3319                NaN                          NaN
# 3320                NaN                          NaN
# 3321                NaN                          NaN
# 3322                NaN                          NaN
#
#       primary_energy_consumption  energy_per_capita  biofuel_consumption  \
# 3304                      45.729           1392.098                  0.0
# 3305                      46.179           1368.197                  0.0
# 3306                      43.954           1267.446                  0.0
# 3307                      47.546           1334.257                  0.0
# 3308                      51.823           1414.954                  0.0
# 3309                      57.020           1514.514                  0.0
# 3310                      57.438           1483.949                  0.0
# 3311                      56.747           1426.097                  0.0
# 3312                      62.102           1518.323                  0.0
# 3313                      67.415           1603.931                  0.0
# 3314                      69.737           1615.110                  0.0
# 3315                      69.137           1559.140                  0.0
# 3316                      72.584           1594.543                  0.0
# 3317                      78.483           1680.586                  0.0
# 3318                      89.885           1877.383                  0.0
# 3319                      93.513           1906.408                  0.0
# 3320                         NaN                NaN                  0.0
# 3321                         NaN                NaN                  0.0
# 3322                         NaN                NaN                  0.0
#
#       low_carbon_consumption  renewables_consumption
# 3304                     NaN                     NaN
# 3305                     NaN                     NaN
# 3306                     NaN                     NaN
# 3307                     NaN                     NaN
# 3308                     NaN                     NaN
# 3309                     NaN                     NaN
# 3310                     NaN                     NaN
# 3311                     NaN                     NaN
# 3312                     NaN                     NaN
# 3313                     NaN                     NaN
# 3314                     NaN                     NaN
# 3315                     NaN                     NaN
# 3316                     NaN                     NaN
# 3317                     NaN                     NaN
# 3318                     NaN                     NaN
# 3319                     NaN                     NaN
# 3320                     NaN                     NaN
# 3321                     NaN                     NaN
# 3322                     NaN                     NaN

# %%
null_sources_africa = []
for i in null_sources_countries:
    if i in africa:
        null_sources_africa.append(i)
'Kenya' in null_sources_africa
# Out:
# False

# %%
non_null_sources_africa = list(set(africa)-set(null_sources_africa))
non_null_sources_africa
# Out:
# ['Nigeria',
#  'Sudan',
#  'South Africa',
#  'Morocco',
#  'Libya',
#  'São Tomé and Príncipe',
#  'Republic of Congo',
#  'Chad',
#  'Zambia',
#  'Democratic Republic of the Congo',
#  'Zimbabwe',
#  'Egypt',
#  'The Gambia',
#  'Madagascar',
#  'Angola',
#  'Ethiopia',
#  'Gabon',
#  'Tunisia',
#  'Ivory Coast',
#  'Cabo Verde',
#  'Algeria',
#  'Kenya']

# %%
prim_en_cons.loc[(prim_en_cons["country"] == "Kenya") & (prim_en_cons["year"] > 2000)]
# Out:
#      iso_code country  year  nuclear_consumption  coal_consumption  \
# 3304      KEN   Kenya  2001                  NaN               NaN
# 3305      KEN   Kenya  2002                  NaN               NaN
# 3306      KEN   Kenya  2003                  NaN               NaN
# 3307      KEN   Kenya  2004                  NaN               NaN
# 3308      KEN   Kenya  2005                  NaN               NaN
# 3309      KEN   Kenya  2006                  NaN               NaN
# 3310      KEN   Kenya  2007                  NaN               NaN
# 3311      KEN   Kenya  2008                  NaN               NaN
# 3312      KEN   Kenya  2009                  NaN               NaN
# 3313      KEN   Kenya  2010                  NaN               NaN
# 3314      KEN   Kenya  2011                  NaN               NaN
# 3315      KEN   Kenya  2012                  NaN               NaN
# 3316      KEN   Kenya  2013                  NaN               NaN
# 3317      KEN   Kenya  2014                  NaN               NaN
# 3318      KEN   Kenya  2015                  NaN               NaN
# 3319      KEN   Kenya  2016                  NaN               NaN
# 3320      KEN   Kenya  2017                  NaN               NaN
# 3321      KEN   Kenya  2018                  NaN               NaN
# 3322      KEN   Kenya  2019                  NaN               NaN
#
#       hydro_consumption  oil_consumption  gas_consumption  wind_consumption  \
# 3304                NaN              NaN              NaN               NaN
# 3305                NaN              NaN              NaN               NaN
# 3306                NaN              NaN              NaN               NaN
# 3307                NaN              NaN              NaN               NaN
# 3308                NaN              NaN              NaN               NaN
# 3309                NaN              NaN              NaN               NaN
# 3310                NaN              NaN              NaN               NaN
# 3311                NaN              NaN              NaN               NaN
# 3312                NaN              NaN              NaN               NaN
# 3313                NaN              NaN              NaN               NaN
# 3314                NaN              NaN              NaN               NaN
# 3315                NaN              NaN              NaN               NaN
# 3316                NaN              NaN              NaN               NaN
# 3317                NaN              NaN              NaN               NaN
# 3318                NaN              NaN              NaN               NaN
# 3319                NaN              NaN              NaN               NaN
# 3320                NaN              NaN              NaN               NaN
# 3321                NaN              NaN              NaN               NaN
# 3322                NaN              NaN              NaN               NaN
#
#       solar_consumption  other_renewable_consumption  \
# 3304                NaN                          NaN
# 3305                NaN                          NaN
# 3306                NaN                          NaN
# 3307                NaN                          NaN
# 3308                NaN                          NaN
# 3309                NaN                          NaN
# 3310                NaN                          NaN
# 3311                NaN                          NaN
# 3312                NaN                          NaN
# 3313                NaN                          NaN
# 3314                NaN                          NaN
# 3315                NaN                          NaN
# 3316                NaN                          NaN
# 3317                NaN                          NaN
# 3318                NaN                          NaN
# 3319                NaN                          NaN
# 3320                NaN                          NaN
# 3321                NaN                          NaN
# 3322                NaN                          NaN
#
#       primary_energy_consumption  energy_per_capita  biofuel_consumption  \
# 3304                      45.729           1392.098                  0.0
# 3305                      46.179           1368.197                  0.0
# 3306                      43.954           1267.446                  0.0
# 3307                      47.546           1334.257                  0.0
# 3308                      51.823           1414.954                  0.0
# 3309                      57.020           1514.514                  0.0
# 3310                      57.438           1483.949                  0.0
# 3311                      56.747           1426.097                  0.0
# 3312                      62.102           1518.323                  0.0
# 3313                      67.415           1603.931                  0.0
# 3314                      69.737           1615.110                  0.0
# 3315                      69.137           1559.140                  0.0
# 3316                      72.584           1594.543                  0.0
# 3317                      78.483           1680.586                  0.0
# 3318                      89.885           1877.383                  0.0
# 3319                      93.513           1906.408                  0.0
# 3320                         NaN                NaN                  0.0
# 3321                         NaN                NaN                  0.0
# 3322                         NaN                NaN                  0.0
#
#       low_carbon_consumption  renewables_consumption
# 3304                     NaN                     NaN
# 3305                     NaN                     NaN
# 3306                     NaN                     NaN
# 3307                     NaN                     NaN
# 3308                     NaN                     NaN
# 3309                     NaN                     NaN
# 3310                     NaN                     NaN
# 3311                     NaN                     NaN
# 3312                     NaN                     NaN
# 3313                     NaN                     NaN
# 3314                     NaN                     NaN
# 3315                     NaN                     NaN
# 3316                     NaN                     NaN
# 3317                     NaN                     NaN
# 3318                     NaN                     NaN
# 3319                     NaN                     NaN
# 3320                     NaN                     NaN
# 3321                     NaN                     NaN
# 3322                     NaN                     NaN
