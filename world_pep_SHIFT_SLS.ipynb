# %% [markdown]
# # Creation and EDA of World Primary Energy Production

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# ## Creating the Dataframes

# %%
path = r'/Users/sebastianlorenzen-schmidt/neuefische/capstone_project/data/energy_prod_world' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=False, header=0, sep=';')
    df['country'] = filename
    li.append(df)

world_frame = pd.concat(li, axis=0, ignore_index=True)

# %%
world_frame['country']
# Out:
# 0        /Users/sebastianlorenzen-schmidt/neuefische/ca...
# 1        /Users/sebastianlorenzen-schmidt/neuefische/ca...
# 2        /Users/sebastianlorenzen-schmidt/neuefische/ca...
# 3        /Users/sebastianlorenzen-schmidt/neuefische/ca...
# 4        /Users/sebastianlorenzen-schmidt/neuefische/ca...
#                                ...
# 17250    /Users/sebastianlorenzen-schmidt/neuefische/ca...
# 17251    /Users/sebastianlorenzen-schmidt/neuefische/ca...
# 17252    /Users/sebastianlorenzen-schmidt/neuefische/ca...
# 17253    /Users/sebastianlorenzen-schmidt/neuefische/ca...
# 17254    /Users/sebastianlorenzen-schmidt/neuefische/ca...
# Name: country, Length: 17255, dtype: object

# %%
world_frame['country'] = world_frame['country'].replace('/Users/sebastianlorenzen-schmidt/neuefische/capstone_project/data/energy_prod_world/','',regex = True)
world_frame['country']
# Out:
# 0        Ethiopia.csv
# 1        Ethiopia.csv
# 2        Ethiopia.csv
# 3        Ethiopia.csv
# 4        Ethiopia.csv
#              ...
# 17250      Guinea.csv
# 17251      Guinea.csv
# 17252      Guinea.csv
# 17253      Guinea.csv
# 17254      Guinea.csv
# Name: country, Length: 17255, dtype: object

# %%
world_frame['country'] = world_frame['country'].replace('.csv','',regex = True)
world_frame['country']
# Out:
# 0        Ethiopia
# 1        Ethiopia
# 2        Ethiopia
# 3        Ethiopia
# 4        Ethiopia
#            ...
# 17250      Guinea
# 17251      Guinea
# 17252      Guinea
# 17253      Guinea
# 17254      Guinea
# Name: country, Length: 17255, dtype: object

# %%
world_frame[world_frame['country']== 'Zimbabwe']
# Out:
#                Unnamed: 0  Oil           Coal  Gas Hydroelectricity Nuclear  \
# 1736  1900-01-01 00:00:00  NaN              0  NaN                0     NaN
# 1737  1901-01-01 00:00:00  NaN              0  NaN                0     NaN
# 1738  1902-01-01 00:00:00  NaN              0  NaN                0     NaN
# 1739  1903-01-01 00:00:00  NaN       0,350063  NaN                0     NaN
# 1740  1904-01-01 00:00:00  NaN       0,439614  NaN                0     NaN
# ...                   ...  ...            ...  ...              ...     ...
# 1848  2012-01-01 00:00:00  0.0  11,5491740586  0.0     15,245713502     0.0
# 1849  2013-01-01 00:00:00  0.0   22,569300115  0.0     14,131429246     0.0
# 1850  2014-01-01 00:00:00  0.0   41,902173592  0.0     15,362856677     0.0
# 1851  2015-01-01 00:00:00  0.0   31,407550016  0.0     14,114286626     0.0
# 1852  2016-01-01 00:00:00  0.0   19,557284794  0.0     8,4485715157     0.0
#
#      Biomass and Waste Wind    Fuel Ethanol Peat Geothermal  \
# 1736               NaN  NaN             NaN  NaN        NaN
# 1737               NaN  NaN             NaN  NaN        NaN
# 1738               NaN  NaN             NaN  NaN        NaN
# 1739               NaN  NaN             NaN  NaN        NaN
# 1740               NaN  NaN             NaN  NaN        NaN
# ...                ...  ...             ...  ...        ...
# 1848     0,46666667093  0.0               0  NaN        0.0
# 1849     0,46111108971  0.0  0,013137832989  NaN        0.0
# 1850      0,4000000103  0.0   0,23224793664  NaN        0.0
# 1851      0,3583333256  0.0   0,24675918773  NaN        0.0
# 1852     0,33611110539  0.0   0,27910686973  NaN        0.0
#
#      Solar, Tide, Wave, Fuel Cell Biodiesel   country
# 1736                          NaN       NaN  Zimbabwe
# 1737                          NaN       NaN  Zimbabwe
# 1738                          NaN       NaN  Zimbabwe
# 1739                          NaN       NaN  Zimbabwe
# 1740                          NaN       NaN  Zimbabwe
# ...                           ...       ...       ...
# 1848               0,014285713989       0.0  Zimbabwe
# 1849               0,020000000515       0.0  Zimbabwe
# 1850               0,020000000515       0.0  Zimbabwe
# 1851               0,028571429141       0.0  Zimbabwe
# 1852               0,034285714504       0.0  Zimbabwe
#
# [117 rows x 14 columns]

# %% [markdown]
# Making sure countries are spelled correctly

# %%
world_frame['country'] = world_frame['country'].replace('_',' ',regex = True)
world_frame['country'] = world_frame['country'].str.title()

world_frame[world_frame['country']=='French Polynesia']
# Out:
#                 Unnamed: 0  Oil Coal  Gas Hydroelectricity Nuclear  \
# 10381  1900-01-01 00:00:00  NaN  NaN  NaN                0     NaN
# 10382  1901-01-01 00:00:00  NaN  NaN  NaN                0     NaN
# 10383  1902-01-01 00:00:00  NaN  NaN  NaN                0     NaN
# 10384  1903-01-01 00:00:00  NaN  NaN  NaN                0     NaN
# 10385  1904-01-01 00:00:00  NaN  NaN  NaN                0     NaN
# ...                    ...  ...  ...  ...              ...     ...
# 10493  2012-01-01 00:00:00  0.0  0.0  0.0    0,59142856589     0.0
# 10494  2013-01-01 00:00:00  0.0  0.0  0.0    0,60000001545     0.0
# 10495  2014-01-01 00:00:00  0.0  0.0  0.0    0,48571430819     0.0
# 10496  2015-01-01 00:00:00  0.0  0.0  0.0    0,48571430819     0.0
# 10497  2016-01-01 00:00:00  0.0  0.0  0.0    0,54285716182     0.0
#
#       Biomass and Waste             Wind Fuel Ethanol Peat Geothermal  \
# 10381               NaN              NaN          NaN  NaN        NaN
# 10382               NaN              NaN          NaN  NaN        NaN
# 10383               NaN              NaN          NaN  NaN        NaN
# 10384               NaN              NaN          NaN  NaN        NaN
# 10385               NaN              NaN          NaN  NaN        NaN
# ...                 ...              ...          ...  ...        ...
# 10493               0.0  0,0008571428626          0.0  NaN        0.0
# 10494               0.0  0,0008571428626          0.0  NaN        0.0
# 10495               0.0  0,0008571428626          0.0  NaN        0.0
# 10496               0.0  0,0008571428626          0.0  NaN        0.0
# 10497               0.0  0,0008571428626          0.0  NaN        0.0
#
#       Solar, Tide, Wave, Fuel Cell Biodiesel           country
# 10381                          NaN       NaN  French Polynesia
# 10382                          NaN       NaN  French Polynesia
# 10383                          NaN       NaN  French Polynesia
# 10384                          NaN       NaN  French Polynesia
# 10385                          NaN       NaN  French Polynesia
# ...                            ...       ...               ...
# 10493               0,054285717345       0.0  French Polynesia
# 10494               0,065714284582       0.0  French Polynesia
# 10495                0,08000000206       0.0  French Polynesia
# 10496               0,097142861638       0.0  French Polynesia
# 10497               0,105714282123       0.0  French Polynesia
#
# [117 rows x 14 columns]

# %% [markdown]
# Replacing the , in the numbers with a .

# %%
world_frame = world_frame.replace(',','.',regex = True)
world_frame
# Out:
#                 Unnamed: 0 Oil Coal Gas Hydroelectricity Nuclear  \
# 0      1980-01-01 00:00:00   0    0   0     1.3514285622       0
# 1      1981-01-01 00:00:00   0    0   0     1.4342857994       0
# 2      1982-01-01 00:00:00   0    0   0     1.6400000306       0
# 3      1983-01-01 00:00:00   0    0   0     1.7799999935       0
# 4      1984-01-01 00:00:00   0    0   0     1.9514285195       0
# ...                    ...  ..  ...  ..              ...     ...
# 17250  2012-01-01 00:00:00   0    0   0     1.3999999779       0
# 17251  2013-01-01 00:00:00   0    0   0      1.374285699       0
# 17252  2014-01-01 00:00:00   0    0   0     1.2285714519       0
# 17253  2015-01-01 00:00:00   0    0   0    1.08571431201       0
# 17254  2016-01-01 00:00:00   0    0   0    1.12857144351       0
#
#       Biomass and Waste Wind Fuel Ethanol Peat Geothermal  \
# 0                     0    0            0  NaN          0
# 1                     0    0            0  NaN          0
# 2                     0    0            0  NaN          0
# 3                     0    0            0  NaN          0
# 4                     0    0            0  NaN          0
# ...                 ...  ...          ...  ...        ...
# 17250                 0    0            0  NaN          0
# 17251                 0    0            0  NaN          0
# 17252                 0    0            0  NaN          0
# 17253                 0    0            0  NaN          0
# 17254                 0    0            0  NaN          0
#
#       Solar, Tide, Wave, Fuel Cell Biodiesel   country
# 0                                0       NaN  Ethiopia
# 1                                0       NaN  Ethiopia
# 2                                0       NaN  Ethiopia
# 3                                0       NaN  Ethiopia
# 4                                0       NaN  Ethiopia
# ...                            ...       ...       ...
# 17250              0.0025714284715       0.0    Guinea
# 17251              0.0028571427978       0.0    Guinea
# 17252              0.0057142855956       0.0    Guinea
# 17253              0.0085714287423       0.0    Guinea
# 17254              0.0085714287423       0.0    Guinea
#
# [17255 rows x 14 columns]

# %%
world_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17255 entries, 0 to 17254
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    17255 non-null  object
#  1   Oil                           13175 non-null  object
#  2   Coal                          12615 non-null  object
#  3   Gas                           12695 non-null  object
#  4   Hydroelectricity              14454 non-null  object
#  5   Nuclear                       9254 non-null   object
#  6   Biomass and Waste             7335 non-null   object
#  7   Wind                          7335 non-null   object
#  8   Fuel Ethanol                  7281 non-null   object
#  9   Peat                          1680 non-null   object
#  10  Geothermal                    8534 non-null   object
#  11  Solar, Tide, Wave, Fuel Cell  7335 non-null   object
#  12  Biodiesel                     3502 non-null   object
#  13  country                       17255 non-null  object
# dtypes: object(14)
# memory usage: 1.8+ MB

# %% [markdown]
# Renaming columns to standard

# %%
cols = world_frame.columns.to_list()

cols = [col.replace(' ','_')for col in cols]
cols = [col.replace(',','')for col in cols]
cols = [col.lower() for col in cols]
cols = [col.replace('unnamed:_0', 'year')for col in cols]

world_frame.columns = cols

world_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17255 entries, 0 to 17254
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       17255 non-null  object
#  1   oil                        13175 non-null  object
#  2   coal                       12615 non-null  object
#  3   gas                        12695 non-null  object
#  4   hydroelectricity           14454 non-null  object
#  5   nuclear                    9254 non-null   object
#  6   biomass_and_waste          7335 non-null   object
#  7   wind                       7335 non-null   object
#  8   fuel_ethanol               7281 non-null   object
#  9   peat                       1680 non-null   object
#  10  geothermal                 8534 non-null   object
#  11  solar_tide_wave_fuel_cell  7335 non-null   object
#  12  biodiesel                  3502 non-null   object
#  13  country                    17255 non-null  object
# dtypes: object(14)
# memory usage: 1.8+ MB

# %% [markdown]
# assigning correct data types

# %%
#year to datetime, extracting year only(int64)
world_frame['year'] = pd.to_datetime(world_frame['year'],yearfirst=True, format= '%Y %m %d').dt.year
world_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17255 entries, 0 to 17254
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       17255 non-null  int64
#  1   oil                        13175 non-null  object
#  2   coal                       12615 non-null  object
#  3   gas                        12695 non-null  object
#  4   hydroelectricity           14454 non-null  object
#  5   nuclear                    9254 non-null   object
#  6   biomass_and_waste          7335 non-null   object
#  7   wind                       7335 non-null   object
#  8   fuel_ethanol               7281 non-null   object
#  9   peat                       1680 non-null   object
#  10  geothermal                 8534 non-null   object
#  11  solar_tide_wave_fuel_cell  7335 non-null   object
#  12  biodiesel                  3502 non-null   object
#  13  country                    17255 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 1.8+ MB

# %%
#casting numeric columns to numeric datatypes
cols = world_frame.columns.to_list()
removes = ['year', 'country']
[cols.remove(col)for col in removes]

for col in cols:
    world_frame[col]= pd.to_numeric(world_frame[col],errors='ignore')

print(world_frame.info())
world_frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17255 entries, 0 to 17254
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       17255 non-null  int64
#  1   oil                        13175 non-null  float64
#  2   coal                       12615 non-null  float64
#  3   gas                        12695 non-null  float64
#  4   hydroelectricity           14454 non-null  float64
#  5   nuclear                    9254 non-null   float64
#  6   biomass_and_waste          7335 non-null   float64
#  7   wind                       7335 non-null   float64
#  8   fuel_ethanol               7281 non-null   float64
#  9   peat                       1680 non-null   float64
#  10  geothermal                 8534 non-null   float64
#  11  solar_tide_wave_fuel_cell  7335 non-null   float64
#  12  biodiesel                  3502 non-null   float64
#  13  country                    17255 non-null  object
# dtypes: float64(12), int64(1), object(1)
# memory usage: 1.8+ MB
# None
#        year  oil  coal  gas  hydroelectricity  nuclear  biomass_and_waste  \
# 0      1980  0.0   0.0  0.0          1.351429      0.0                0.0
# 1      1981  0.0   0.0  0.0          1.434286      0.0                0.0
# 2      1982  0.0   0.0  0.0          1.640000      0.0                0.0
# 3      1983  0.0   0.0  0.0          1.780000      0.0                0.0
# 4      1984  0.0   0.0  0.0          1.951429      0.0                0.0
# ...     ...  ...   ...  ...               ...      ...                ...
# 17250  2012  0.0   0.0  0.0          1.400000      0.0                0.0
# 17251  2013  0.0   0.0  0.0          1.374286      0.0                0.0
# 17252  2014  0.0   0.0  0.0          1.228571      0.0                0.0
# 17253  2015  0.0   0.0  0.0          1.085714      0.0                0.0
# 17254  2016  0.0   0.0  0.0          1.128571      0.0                0.0
#
#        wind  fuel_ethanol  peat  geothermal  solar_tide_wave_fuel_cell  \
# 0       0.0           0.0   NaN         0.0                   0.000000
# 1       0.0           0.0   NaN         0.0                   0.000000
# 2       0.0           0.0   NaN         0.0                   0.000000
# 3       0.0           0.0   NaN         0.0                   0.000000
# 4       0.0           0.0   NaN         0.0                   0.000000
# ...     ...           ...   ...         ...                        ...
# 17250   0.0           0.0   NaN         0.0                   0.002571
# 17251   0.0           0.0   NaN         0.0                   0.002857
# 17252   0.0           0.0   NaN         0.0                   0.005714
# 17253   0.0           0.0   NaN         0.0                   0.008571
# 17254   0.0           0.0   NaN         0.0                   0.008571
#
#        biodiesel   country
# 0            NaN  Ethiopia
# 1            NaN  Ethiopia
# 2            NaN  Ethiopia
# 3            NaN  Ethiopia
# 4            NaN  Ethiopia
# ...          ...       ...
# 17250        0.0    Guinea
# 17251        0.0    Guinea
# 17252        0.0    Guinea
# 17253        0.0    Guinea
# 17254        0.0    Guinea
#
# [17255 rows x 14 columns]

# %% [markdown]
# ## Adding ISO-CODE to dataframe

# %%
df_codes = pd.read_csv('/Users/sebastianlorenzen-schmidt/neuefische/capstone_project/data/location.csv')
df_codes
# Out:
#      Unnamed: 0  location_id location_code location_name_short_en    level  \
# 0             0            0           ABW                  Aruba  country
# 1             1            1           AFG            Afghanistan  country
# 2             2            2           AGO                 Angola  country
# 3             3            3           AIA               Anguilla  country
# 4             4            4           ALB                Albania  country
# ..          ...          ...           ...                    ...      ...
# 253         253          354             3                Oceania   region
# 254         254          355             4                 Europe   region
# 255         255          356             5          North America   region
# 256         256          357             6          South America   region
# 257         257          358             7                  Other   region
#
#      parent_id
# 0        356.0
# 1        353.0
# 2        352.0
# 3        356.0
# 4        355.0
# ..         ...
# 253        NaN
# 254        NaN
# 255        NaN
# 256        NaN
# 257        NaN
#
# [258 rows x 6 columns]

# %%
df_codes.drop(['Unnamed: 0','location_id','level','parent_id'],axis=1, inplace = True)
df_codes
# Out:
#     location_code location_name_short_en
# 0             ABW                  Aruba
# 1             AFG            Afghanistan
# 2             AGO                 Angola
# 3             AIA               Anguilla
# 4             ALB                Albania
# ..            ...                    ...
# 253             3                Oceania
# 254             4                 Europe
# 255             5          North America
# 256             6          South America
# 257             7                  Other
#
# [258 rows x 2 columns]

# %%
cols = df_codes.columns.to_list()
for col in cols:
   col = col.replace('location_name_short_en','country')

df_codes.columns = cols

df_codes
# Out:
#     location_code location_name_short_en
# 0             ABW                  Aruba
# 1             AFG            Afghanistan
# 2             AGO                 Angola
# 3             AIA               Anguilla
# 4             ALB                Albania
# ..            ...                    ...
# 253             3                Oceania
# 254             4                 Europe
# 255             5          North America
# 256             6          South America
# 257             7                  Other
#
# [258 rows x 2 columns]

# %% [markdown]
# Joining df_codes to world_frame to get the iso-code

# %%
world_frame2 =world_frame.merge(df_codes, how='outer', left_on='country', right_on='location_name_short_en', 
                                left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), 
                                copy=True, indicator=False, validate=None)

# %%
#checking if merged correctly
world_frame2
# Out:
#          year  oil  coal  gas  hydroelectricity  nuclear  biomass_and_waste  \
# 0      1980.0  0.0   0.0  0.0          1.351429      0.0                0.0
# 1      1981.0  0.0   0.0  0.0          1.434286      0.0                0.0
# 2      1982.0  0.0   0.0  0.0          1.640000      0.0                0.0
# 3      1983.0  0.0   0.0  0.0          1.780000      0.0                0.0
# 4      1984.0  0.0   0.0  0.0          1.951429      0.0                0.0
# ...       ...  ...   ...  ...               ...      ...                ...
# 17327     NaN  NaN   NaN  NaN               NaN      NaN                NaN
# 17328     NaN  NaN   NaN  NaN               NaN      NaN                NaN
# 17329     NaN  NaN   NaN  NaN               NaN      NaN                NaN
# 17330     NaN  NaN   NaN  NaN               NaN      NaN                NaN
# 17331     NaN  NaN   NaN  NaN               NaN      NaN                NaN
#
#        wind  fuel_ethanol  peat  geothermal  solar_tide_wave_fuel_cell  \
# 0       0.0           0.0   NaN         0.0                        0.0
# 1       0.0           0.0   NaN         0.0                        0.0
# 2       0.0           0.0   NaN         0.0                        0.0
# 3       0.0           0.0   NaN         0.0                        0.0
# 4       0.0           0.0   NaN         0.0                        0.0
# ...     ...           ...   ...         ...                        ...
# 17327   NaN           NaN   NaN         NaN                        NaN
# 17328   NaN           NaN   NaN         NaN                        NaN
# 17329   NaN           NaN   NaN         NaN                        NaN
# 17330   NaN           NaN   NaN         NaN                        NaN
# 17331   NaN           NaN   NaN         NaN                        NaN
#
#        biodiesel   country location_code location_name_short_en
# 0            NaN  Ethiopia           ETH               Ethiopia
# 1            NaN  Ethiopia           ETH               Ethiopia
# 2            NaN  Ethiopia           ETH               Ethiopia
# 3            NaN  Ethiopia           ETH               Ethiopia
# 4            NaN  Ethiopia           ETH               Ethiopia
# ...          ...       ...           ...                    ...
# 17327        NaN       NaN             3                Oceania
# 17328        NaN       NaN             4                 Europe
# 17329        NaN       NaN             5          North America
# 17330        NaN       NaN             6          South America
# 17331        NaN       NaN             7                  Other
#
# [17332 rows x 16 columns]

# %%
#checking on the additional values added by the outer merge
world_frame2['year'].isna().value_counts()
# Out:
# False    17255
# True        77
# Name: year, dtype: int64

# %% [markdown]
# * additional values are rows without a year, so they originate strictly from the df_codes dataframe, since the world_frame has a year in every row
# * fixing this by dropping all the columns, that do not have a year-value
#
#
# ### Recasting year to int

# %%
world_frame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17332 entries, 0 to 17331
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       17255 non-null  float64
#  1   oil                        13175 non-null  float64
#  2   coal                       12615 non-null  float64
#  3   gas                        12695 non-null  float64
#  4   hydroelectricity           14454 non-null  float64
#  5   nuclear                    9254 non-null   float64
#  6   biomass_and_waste          7335 non-null   float64
#  7   wind                       7335 non-null   float64
#  8   fuel_ethanol               7281 non-null   float64
#  9   peat                       1680 non-null   float64
#  10  geothermal                 8534 non-null   float64
#  11  solar_tide_wave_fuel_cell  7335 non-null   float64
#  12  biodiesel                  3502 non-null   float64
#  13  country                    17255 non-null  object
#  14  location_code              15404 non-null  object
#  15  location_name_short_en     15404 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 2.2+ MB

# %%
world_frame2['year'] = world_frame2['year'].values.astype(np.int64) #hardcasting should be avoided, but was necessary in this case, since the datatype was already numeric
world_frame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17332 entries, 0 to 17331
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       17332 non-null  int64
#  1   oil                        13175 non-null  float64
#  2   coal                       12615 non-null  float64
#  3   gas                        12695 non-null  float64
#  4   hydroelectricity           14454 non-null  float64
#  5   nuclear                    9254 non-null   float64
#  6   biomass_and_waste          7335 non-null   float64
#  7   wind                       7335 non-null   float64
#  8   fuel_ethanol               7281 non-null   float64
#  9   peat                       1680 non-null   float64
#  10  geothermal                 8534 non-null   float64
#  11  solar_tide_wave_fuel_cell  7335 non-null   float64
#  12  biodiesel                  3502 non-null   float64
#  13  country                    17255 non-null  object
#  14  location_code              15404 non-null  object
#  15  location_name_short_en     15404 non-null  object
# dtypes: float64(12), int64(1), object(3)
# memory usage: 2.2+ MB

# %% [markdown]
# ## Slicing Frame to desired sample size

# %%
years = range(1990,2017,1)
world_frame3 = world_frame2[world_frame2['year'].isin(years)]

# %%
world_frame3
# Out:
#        year  oil  coal  gas  hydroelectricity  nuclear  biomass_and_waste  \
# 10     1990  0.0   0.0  0.0          3.108572      0.0                0.0
# 11     1991  0.0   0.0  0.0          3.134286      0.0                0.0
# 12     1992  0.0   0.0  0.0          3.220000      0.0                0.0
# 13     1993  0.0   0.0  0.0          3.574286      0.0                0.0
# 14     1994  0.0   0.0  0.0          3.828571      0.0                0.0
# ...     ...  ...   ...  ...               ...      ...                ...
# 17250  2012  0.0   0.0  0.0          1.400000      0.0                0.0
# 17251  2013  0.0   0.0  0.0          1.374286      0.0                0.0
# 17252  2014  0.0   0.0  0.0          1.228571      0.0                0.0
# 17253  2015  0.0   0.0  0.0          1.085714      0.0                0.0
# 17254  2016  0.0   0.0  0.0          1.128571      0.0                0.0
#
#        wind  fuel_ethanol  peat  geothermal  solar_tide_wave_fuel_cell  \
# 10      0.0           0.0   NaN         0.0                   0.000000
# 11      0.0           0.0   NaN         0.0                   0.000000
# 12      0.0           0.0   NaN         0.0                   0.000000
# 13      0.0           0.0   NaN         0.0                   0.000000
# 14      0.0           0.0   NaN         0.0                   0.000000
# ...     ...           ...   ...         ...                        ...
# 17250   0.0           0.0   NaN         0.0                   0.002571
# 17251   0.0           0.0   NaN         0.0                   0.002857
# 17252   0.0           0.0   NaN         0.0                   0.005714
# 17253   0.0           0.0   NaN         0.0                   0.008571
# 17254   0.0           0.0   NaN         0.0                   0.008571
#
#        biodiesel   country location_code location_name_short_en
# 10           NaN  Ethiopia           ETH               Ethiopia
# 11           NaN  Ethiopia           ETH               Ethiopia
# 12           NaN  Ethiopia           ETH               Ethiopia
# 13           NaN  Ethiopia           ETH               Ethiopia
# 14           NaN  Ethiopia           ETH               Ethiopia
# ...          ...       ...           ...                    ...
# 17250        0.0    Guinea           GIN                 Guinea
# 17251        0.0    Guinea           GIN                 Guinea
# 17252        0.0    Guinea           GIN                 Guinea
# 17253        0.0    Guinea           GIN                 Guinea
# 17254        0.0    Guinea           GIN                 Guinea
#
# [5521 rows x 16 columns]

# %%
#checking again if dropping the additional columns and the slicing to sample size worked correctly
world_frame[world_frame['year']>1989]
# Out:
#        year  oil  coal  gas  hydroelectricity  nuclear  biomass_and_waste  \
# 10     1990  0.0   0.0  0.0          3.108572      0.0                0.0
# 11     1991  0.0   0.0  0.0          3.134286      0.0                0.0
# 12     1992  0.0   0.0  0.0          3.220000      0.0                0.0
# 13     1993  0.0   0.0  0.0          3.574286      0.0                0.0
# 14     1994  0.0   0.0  0.0          3.828571      0.0                0.0
# ...     ...  ...   ...  ...               ...      ...                ...
# 17250  2012  0.0   0.0  0.0          1.400000      0.0                0.0
# 17251  2013  0.0   0.0  0.0          1.374286      0.0                0.0
# 17252  2014  0.0   0.0  0.0          1.228571      0.0                0.0
# 17253  2015  0.0   0.0  0.0          1.085714      0.0                0.0
# 17254  2016  0.0   0.0  0.0          1.128571      0.0                0.0
#
#        wind  fuel_ethanol  peat  geothermal  solar_tide_wave_fuel_cell  \
# 10      0.0           0.0   NaN         0.0                   0.000000
# 11      0.0           0.0   NaN         0.0                   0.000000
# 12      0.0           0.0   NaN         0.0                   0.000000
# 13      0.0           0.0   NaN         0.0                   0.000000
# 14      0.0           0.0   NaN         0.0                   0.000000
# ...     ...           ...   ...         ...                        ...
# 17250   0.0           0.0   NaN         0.0                   0.002571
# 17251   0.0           0.0   NaN         0.0                   0.002857
# 17252   0.0           0.0   NaN         0.0                   0.005714
# 17253   0.0           0.0   NaN         0.0                   0.008571
# 17254   0.0           0.0   NaN         0.0                   0.008571
#
#        biodiesel   country
# 10           NaN  Ethiopia
# 11           NaN  Ethiopia
# 12           NaN  Ethiopia
# 13           NaN  Ethiopia
# 14           NaN  Ethiopia
# ...          ...       ...
# 17250        0.0    Guinea
# 17251        0.0    Guinea
# 17252        0.0    Guinea
# 17253        0.0    Guinea
# 17254        0.0    Guinea
#
# [5521 rows x 14 columns]

# %% [markdown]
# ### world_frame 3 is the same length as world frame. so we can assume, all rows for the years we do not want in our sample are removed and the frames have been successfully merged and cut!

# %% [markdown]
# ## Finding and removing unneeded columns from merged Frame

# %%
world_frame3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5521 entries, 10 to 17254
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       5521 non-null   int64
#  1   oil                        5521 non-null   float64
#  2   coal                       5521 non-null   float64
#  3   gas                        5521 non-null   float64
#  4   hydroelectricity           5520 non-null   float64
#  5   nuclear                    5521 non-null   float64
#  6   biomass_and_waste          5521 non-null   float64
#  7   wind                       5521 non-null   float64
#  8   fuel_ethanol               5489 non-null   float64
#  9   peat                       0 non-null      float64
#  10  geothermal                 5520 non-null   float64
#  11  solar_tide_wave_fuel_cell  5521 non-null   float64
#  12  biodiesel                  3502 non-null   float64
#  13  country                    5521 non-null   object
#  14  location_code              4783 non-null   object
#  15  location_name_short_en     4783 non-null   object
# dtypes: float64(12), int64(1), object(3)
# memory usage: 733.3+ KB

# %% [markdown]
# * peat does not contain any values -> empty column can go
# * country entries are in two columns -> dropping location_name_short_en (since it is longer and annoying to write down all the time)
# * missing value in hydroelectricity
# * missing value in geothermal
# * missing values in fuel_ethanol

# %%
world_frame4 = world_frame3.drop(['peat','location_name_short_en'], axis = 1,)
world_frame4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5521 entries, 10 to 17254
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       5521 non-null   int64
#  1   oil                        5521 non-null   float64
#  2   coal                       5521 non-null   float64
#  3   gas                        5521 non-null   float64
#  4   hydroelectricity           5520 non-null   float64
#  5   nuclear                    5521 non-null   float64
#  6   biomass_and_waste          5521 non-null   float64
#  7   wind                       5521 non-null   float64
#  8   fuel_ethanol               5489 non-null   float64
#  9   geothermal                 5520 non-null   float64
#  10  solar_tide_wave_fuel_cell  5521 non-null   float64
#  11  biodiesel                  3502 non-null   float64
#  12  country                    5521 non-null   object
#  13  location_code              4783 non-null   object
# dtypes: float64(11), int64(1), object(2)
# memory usage: 647.0+ KB

# %% [markdown]
# ## Combining columns and adding the calculatory columns

# %%
#filling in 0s so we dont lose values when calculating with NaN
world_frame4.fillna(0,inplace=True)
world_frame4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5521 entries, 10 to 17254
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       5521 non-null   int64
#  1   oil                        5521 non-null   float64
#  2   coal                       5521 non-null   float64
#  3   gas                        5521 non-null   float64
#  4   hydroelectricity           5521 non-null   float64
#  5   nuclear                    5521 non-null   float64
#  6   biomass_and_waste          5521 non-null   float64
#  7   wind                       5521 non-null   float64
#  8   fuel_ethanol               5521 non-null   float64
#  9   geothermal                 5521 non-null   float64
#  10  solar_tide_wave_fuel_cell  5521 non-null   float64
#  11  biodiesel                  5521 non-null   float64
#  12  country                    5521 non-null   object
#  13  location_code              5521 non-null   object
# dtypes: float64(11), int64(1), object(2)
# memory usage: 647.0+ KB

# %% [markdown]
# ### unifying solar column and geothermal column to solar_geothermal_other

# %%
world_frame4['solar_geothermal_other']= (world_frame4['geothermal'] 
                                        + world_frame4['solar_tide_wave_fuel_cell'])

world_frame4['solar_geothermal_other'].isna().value_counts()
# Out:
# False    5521
# Name: solar_geothermal_other, dtype: int64

# %% [markdown]
# ### Unifying biomass_and_waste, fuel_ethanol and biodiesel to biofuel

# %%
world_frame4['biofuel'] = (world_frame4['biomass_and_waste']
                           + world_frame4['fuel_ethanol']
                           + world_frame4['biodiesel'])
world_frame4['biofuel'].isna().value_counts()
# Out:
# False    5521
# Name: biofuel, dtype: int64

# %% [markdown]
# ### Creating aggregated columns for fossil fuels and renewables

# %%
world_frame4['fossil_fuels'] = (world_frame4['oil']
                           + world_frame4['gas']
                           + world_frame4['coal'])
world_frame4['fossil_fuels'].isna().value_counts()
# Out:
# False    5521
# Name: fossil_fuels, dtype: int64

# %%
world_frame4['renewables'] = (world_frame4['biofuel']
                           + world_frame4['hydroelectricity']
                           + world_frame4['wind']
                           + world_frame4['solar_geothermal_other'])
print(world_frame4['renewables'].isna().value_counts())
world_frame4[['renewables','year']][world_frame4['country']== 'Bahamas']
# Out:
# False    5521
# Name: renewables, dtype: int64
#      renewables  year
# 423    0.000000  1990
# 424    0.000000  1991
# 425    0.000000  1992
# 426    0.000000  1993
# 427    0.000000  1994
# 428    0.000000  1995
# 429    0.000000  1996
# 430    0.000000  1997
# 431    0.000000  1998
# 432    0.000000  1999
# 433    0.000000  2000
# 434    0.000000  2001
# 435    0.000000  2002
# 436    0.000000  2003
# 437    0.000000  2004
# 438    0.000000  2005
# 439    0.000000  2006
# 440    0.000000  2007
# 441    0.000000  2008
# 442    0.000000  2009
# 443    0.001429  2010
# 444    0.001714  2011
# 445    0.002571  2012
# 446    0.002571  2013
# 447    0.005714  2014
# 448    0.005714  2015
# 449    0.005714  2016

# %% [markdown]
# ### Calculating columns for total production and shares by category and source

# %%
world_frame4['total_prod'] = (world_frame4['fossil_fuels']
                           + world_frame4['nuclear']
                           + world_frame4['renewables'])
print(world_frame4['total_prod'].isna().value_counts())
world_frame4[['total_prod','country','year']][world_frame4['total_prod']== 0]
# Out:
# False    5521
# Name: total_prod, dtype: int64
#        total_prod        country  year
# 423           0.0        Bahamas  1990
# 424           0.0        Bahamas  1991
# 425           0.0        Bahamas  1992
# 426           0.0        Bahamas  1993
# 427           0.0        Bahamas  1994
# ...           ...            ...   ...
# 16975         0.0  French Guiana  1996
# 16976         0.0  French Guiana  1997
# 16977         0.0  French Guiana  1998
# 16978         0.0  French Guiana  1999
# 16979         0.0  French Guiana  2000
#
# [703 rows x 3 columns]

# %%
world_frame4['fossil_fuel_share'] = world_frame4['fossil_fuels']/world_frame4['total_prod']
world_frame4[['fossil_fuel_share','country','year']][world_frame4['fossil_fuel_share'] == 0]
#world_frame4[['fossil_fuel_share', 'country','year']].info()
# Out:
#        fossil_fuel_share   country  year
# 10                   0.0  Ethiopia  1990
# 11                   0.0  Ethiopia  1991
# 12                   0.0  Ethiopia  1992
# 13                   0.0  Ethiopia  1993
# 14                   0.0  Ethiopia  1994
# ...                  ...       ...   ...
# 17250                0.0    Guinea  2012
# 17251                0.0    Guinea  2013
# 17252                0.0    Guinea  2014
# 17253                0.0    Guinea  2015
# 17254                0.0    Guinea  2016
#
# [1756 rows x 3 columns]

# %%
world_frame4['country'][world_frame4['fossil_fuel_share'] == 0]
# Out:
# 10       Ethiopia
# 11       Ethiopia
# 12       Ethiopia
# 13       Ethiopia
# 14       Ethiopia
#            ...
# 17250      Guinea
# 17251      Guinea
# 17252      Guinea
# 17253      Guinea
# 17254      Guinea
# Name: country, Length: 1756, dtype: object
